# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %% [markdown]
# # Series

# %%
series_obj1 = Series([2,3,4,5,6,7,8])
series_obj1
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# 6    8
# dtype: int64

# %%
series_obj2 = Series([2,3,4,7],index = ['row 1','row 2','row 3','row 4'])
series_obj2
# Out:
# row 1    2
# row 2    3
# row 3    4
# row 4    7
# dtype: int64

# %% [markdown]
# # Selecting and Retriving data from the series object

# %%
series_obj2['row 3'] #select data with index 0,1,2.... or using row label : row1 , row2
# Out:
# 4

# %%
series_obj1[2:5] # when use slice operator : start from the index,exclude the index
# Out:
# 2    4
# 3    5
# 4    6
# dtype: int64

# %%
series_obj1[[2,4,6]]
# Out:
# 2    4
# 4    6
# 6    8
# dtype: int64

# %% [markdown]
# # DataFrame

# %%
np.floor(np.random.rand(36).reshape(6,6)*100)
# Out:
# array([[17.,  0., 61., 51., 77., 86.],
#        [11., 51., 13., 57., 97., 44.],
#        [79., 79., 35., 57., 34., 43.],
#        [61., 46., 67., 69., 96.,  8.],
#        [96., 87., 10., 82., 49., 10.],
#        [18., 72., 53., 79., 94., 83.]])

# %%
df_obj1 = DataFrame(np.floor(np.random.rand(36).reshape(6,6)*100))
df_obj1
# Out:
#       0     1     2     3     4     5
# 0  38.0  71.0  37.0  58.0  22.0  64.0
# 1  88.0  20.0  44.0  75.0   1.0  68.0
# 2  14.0  87.0  32.0  89.0  19.0  43.0
# 3  95.0  90.0  42.0   9.0  72.0  35.0
# 4   7.0  78.0  18.0  57.0  13.0  47.0
# 5  40.0  42.0  95.0  28.0  83.0  30.0

# %%
ind = ['row1','row2','row3','row4','row5','row6']
col = ['col1','col2','col3','col4','col5','col6']
ind
# Out:
# ['row1', 'row2', 'row3', 'row4', 'row5', 'row6']

# %%
col
# Out:
# ['col1', 'col2', 'col3', 'col4', 'col5', 'col6']

# %%
df_obj2 = DataFrame(np.floor(np.random.rand(36).reshape(6,6)*100),index=ind,columns=col)
df_obj2
# Out:
#       col1  col2  col3  col4  col5  col6
# row1  72.0  56.0  45.0  14.0  50.0  18.0
# row2  14.0  65.0  80.0  76.0  78.0  90.0
# row3  62.0  76.0  25.0  60.0  32.0  15.0
# row4  98.0  73.0  80.0  77.0  47.0  51.0
# row5  29.0  48.0   5.0  86.0  91.0   4.0
# row6  41.0  50.0  13.0  79.0   5.0  11.0

# %%
df_obj2.loc['row3','col2']
# Out:
# 76.0

# %%
df_obj2.loc[['row3','row4'],['col2','col3','col4']]
# Out:
#       col2  col3  col4
# row3  76.0  25.0  60.0
# row4  73.0  80.0  77.0

# %%
df_obj2.iloc[2,3]
# Out:
# 60.0

# %%
df_obj2.loc[ : , 'col3':]
# Out:
#       col3  col4  col5  col6
# row1  45.0  14.0  50.0  18.0
# row2  80.0  76.0  78.0  90.0
# row3  25.0  60.0  32.0  15.0
# row4  80.0  77.0  47.0  51.0
# row5   5.0  86.0  91.0   4.0
# row6  13.0  79.0   5.0  11.0

# %% [markdown]
# # Loading from external source,csv

# %%
cars = pd.read_csv('mtcars.csv')

# %%
cars.head()
# Out:
#         car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1   Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3  Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     1

# %%
col = ['car_model','mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']

# %%
cars.columns = col

# %%
cars.tail(10)
# Out:
#            car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 22       AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# 23        Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# 24  Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# 25         Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# 26     Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# 27      Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 28    Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# 29      Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# 30     Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# 31        Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 22     2
# 23     4
# 24     2
# 25     1
# 26     2
# 27     2
# 28     4
# 29     6
# 30     8
# ...

# %%
cars.shape
# Out:
# (32, 12)

# %% [markdown]
# # filtering data

# %%
cars.head()
# Out:
#         car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1   Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3  Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     1

# %%
cars[cars.mpg>20] [cars.mpg<25]
# Out:
# C:\Users\Vedhanarayanan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 0      4
# 1      4
# 2      1
# 3      1
# 4      1
# 20     1
# 31     2

# %%
cars[(cars.mpg>20)] [(cars.mpg<25)]
# Out:
# C:\Users\Vedhanarayanan\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#          car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0        Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1    Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3   Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4       Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 20   Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 0      4
# 1      4
# 2      1
# 3      1
# 4      1
# 20     1
# 31     2

# %%
cars[(cars.mpg>30)] = np.nan

# %%
cars
# Out:
#               car_model   mpg  cyl   disp     hp  drat     wt   qsec   vs  \
# 0             Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0
# 1         Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0
# 2            Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0
# 3        Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0
# 4            Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0
# 5               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 6            Duster 360  14.3  8.0  360.0  245.0  3.21  3.570  15.84  0.0
# 7             Valiant 2  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 8               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 9              Merc 280  19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0
# 10            Merc 280C  17.8  6.0  167.6  123.0  3.92  3.440  18.90  1.0
# 11           Merc 450SE  16.4  8.0  275.8  180.0  3.07  4.070  17.40  0.0
# ...

# %%
cars.fillna(method='ffill')
# Out:
#               car_model   mpg  cyl   disp     hp  drat     wt   qsec   vs  \
# 0             Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0
# 1         Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0
# 2            Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0
# 3        Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0
# 4            Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0
# 5               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 6            Duster 360  14.3  8.0  360.0  245.0  3.21  3.570  15.84  0.0
# 7             Valiant 2  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 8               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 9              Merc 280  19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0
# 10            Merc 280C  17.8  6.0  167.6  123.0  3.92  3.440  18.90  1.0
# 11           Merc 450SE  16.4  8.0  275.8  180.0  3.07  4.070  17.40  0.0
# ...

# %%
cars.fillna(method='bfill')
# Out:
#               car_model   mpg  cyl   disp     hp  drat     wt   qsec   vs  \
# 0             Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0
# 1         Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0
# 2            Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0
# 3        Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0
# 4            Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0
# 5               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 6            Duster 360  14.3  8.0  360.0  245.0  3.21  3.570  15.84  0.0
# 7             Valiant 2  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 8               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 9              Merc 280  19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0
# 10            Merc 280C  17.8  6.0  167.6  123.0  3.92  3.440  18.90  1.0
# 11           Merc 450SE  16.4  8.0  275.8  180.0  3.07  4.070  17.40  0.0
# ...

# %%
cars.fillna(cars.mean())
# Out:
#               car_model     mpg  cyl        disp          hp      drat  \
# 0             Mazda RX4  21.000  6.0  160.000000  110.000000  3.900000
# 1         Mazda RX4 Wag  21.000  6.0  160.000000  110.000000  3.900000
# 2            Datsun 710  22.800  4.0  108.000000   93.000000  3.850000
# 3        Hornet 4 Drive  21.400  6.0  258.000000  110.000000  3.080000
# 4            Datsun 710  22.800  4.0  108.000000   93.000000  3.850000
# 5               Valiant  18.100  6.0  225.000000  105.000000  2.760000
# 6            Duster 360  14.300  8.0  360.000000  245.000000  3.210000
# 7             Valiant 2  18.100  6.0  225.000000  105.000000  2.760000
# 8               Valiant  18.100  6.0  225.000000  105.000000  2.760000
# 9              Merc 280  19.200  6.0  167.600000  123.000000  3.920000
# 10            Merc 280C  17.800  6.0  167.600000  123.000000  3.920000
# 11           Merc 450SE  16.400  8.0  275.800000  180.000000  3.070000
# ...

# %%
cars.dropna()
# Out:
#               car_model   mpg  cyl   disp     hp  drat     wt   qsec   vs  \
# 0             Mazda RX4  21.0  6.0  160.0  110.0  3.90  2.620  16.46  0.0
# 1         Mazda RX4 Wag  21.0  6.0  160.0  110.0  3.90  2.875  17.02  0.0
# 2            Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0
# 3        Hornet 4 Drive  21.4  6.0  258.0  110.0  3.08  3.215  19.44  1.0
# 4            Datsun 710  22.8  4.0  108.0   93.0  3.85  2.320  18.61  1.0
# 5               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 6            Duster 360  14.3  8.0  360.0  245.0  3.21  3.570  15.84  0.0
# 7             Valiant 2  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 8               Valiant  18.1  6.0  225.0  105.0  2.76  3.460  20.22  1.0
# 9              Merc 280  19.2  6.0  167.6  123.0  3.92  3.440  18.30  1.0
# 10            Merc 280C  17.8  6.0  167.6  123.0  3.92  3.440  18.90  1.0
# 11           Merc 450SE  16.4  8.0  275.8  180.0  3.07  4.070  17.40  0.0
# ...

# %% [markdown]
# # Removing Duplicates

# %%
df_dup = DataFrame({'col1':[1,2,2,3,3,3,4],'col2':['a','b','b','c','c','c','d'],'col3':['A','B','B','C','C','C','D']})
df_dup
# Out:
#    col1 col2 col3
# 0     1    a    A
# 1     2    b    B
# 2     2    b    B
# 3     3    c    C
# 4     3    c    C
# 5     3    c    C
# 6     4    d    D

# %%
df_dup.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# 6    False
# dtype: bool

# %%
df_dup.drop_duplicates()
# Out:
#    col1 col2 col3
# 0     1    a    A
# 1     2    b    B
# 3     3    c    C
# 6     4    d    D
